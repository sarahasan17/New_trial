# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahasan17/New_trial/blob/main/poem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import tensorflow

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow.keras.utils as ku
from wordcloud import WordCloud
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

# %% [markdown]
# **LOADING THE DATASET**

# %%
# Reading the text data file
data = open('poem.txt', encoding="utf8").read()

# EDA: Generating WordCloud to visualize
# the text
wordcloud = WordCloud(max_font_size=50,
					max_words=100,
					background_color="black").generate(data)

# Plotting the WordCloud
plt.figure(figsize=(8, 4))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig("WordCloud.png")
plt.show()

# %% [markdown]
# **CREATING THE CORPUS**

# %%
corpus = data.lower().split("\n")
print(corpus[:10])
# Out:
# ['stay, i said', 'to the cut flowers.', 'they bowed', 'their heads lower.', 'stay, i said to the spider,', 'who fled.', 'stay, leaf.', 'it reddened,', 'embarrassed for me and itself.', 'stay, i said to my body.']

# %% [markdown]
# **Fitting the Tokenizer on the Corpus**

# %%
# Fitting the Tokenizer on the Corpus
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)

# Vocabulary count of the corpus
total_words = len(tokenizer.word_index)

print("Total Words:", total_words)
# Out:
# Total Words: 3807

# %%
if corpus.lower() in

# %% [markdown]
# **Generating Embeddings/Vectorization**

# %%
# Converting the text into embeddings
input_sequences = []
for line in corpus:
	token_list = tokenizer.texts_to_sequences([line])[0]

	for i in range(1, len(token_list)):
		n_gram_sequence = token_list[:i+1]
		input_sequences.append(n_gram_sequence)

max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences,
										maxlen=max_sequence_len,
										padding='pre'))
predictors, label = input_sequences[:, :-1], input_sequences[:, -1]
label = ku.to_categorical(label, num_classes=total_words+1)
print(input_sequences)
# Out:
# [[   0    0    0 ...    0  266    3]
#  [   0    0    0 ...  266    3   59]
#  [   0    0    0 ...    0    4    1]
#  ...
#  [   0    0    0 ... 3807   15    4]
#  [   0    0    0 ...   15    4  203]
#  [   0    0    0 ...    4  203   85]]

# %% [markdown]
# **Building the Bi-directional LSTM Model**

# %%
 # Building a Bi-Directional LSTM Model
model = Sequential()
model.add(Embedding(total_words+1, 100,
					input_length=max_sequence_len-1))
model.add(Bidirectional(LSTM(150, return_sequences=True)))
model.add(Dropout(0.2))
model.add(LSTM(100))
model.add(Dense(total_words+1/2, activation='relu',
				kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(total_words+1, activation='softmax'))
model.compile(loss='categorical_crossentropy',
			optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 15, 100)           380800
#
#  bidirectional (Bidirection  (None, 15, 300)           301200
#  al)
#
#  dropout (Dropout)           (None, 15, 300)           0
#
#  lstm_1 (LSTM)               (None, 100)               160400
#
#  dense (Dense)               (None, 3807)              384507
#
#  dense_1 (Dense)             (None, 3808)              14500864
#
# =================================================================
# Total params: 15727771 (60.00 MB)
# Trainable params: 15727771 (60.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# **MODEL TRAINING**

# %%
history = model.fit(predictors, label, epochs=150, batch_size=32, verbose=1)
# Out:
# Epoch 1/150
# 510/510 [==============================] - 31s 29ms/step - loss: 6.9490 - accuracy: 0.0617
# Epoch 2/150
# 510/510 [==============================] - 7s 14ms/step - loss: 6.5304 - accuracy: 0.0635
# Epoch 3/150
# 510/510 [==============================] - 6s 13ms/step - loss: 6.3454 - accuracy: 0.0650
# Epoch 4/150
# 510/510 [==============================] - 7s 13ms/step - loss: 6.2134 - accuracy: 0.0723
# Epoch 5/150
# 510/510 [==============================] - 6s 12ms/step - loss: 6.0975 - accuracy: 0.0808
# Epoch 6/150
# 510/510 [==============================] - 7s 13ms/step - loss: 5.9828 - accuracy: 0.0880
# Epoch 7/150
# 510/510 [==============================] - 6s 12ms/step - loss: 5.8735 - accuracy: 0.0951
# Epoch 8/150
# 510/510 [==============================] - 7s 13ms/step - loss: 5.7678 - accuracy: 0.1000
# Epoch 9/150
# 510/510 [==============================] - 6s 12ms/step - loss: 5.6645 - accuracy: 0.1066
# Epoch 10/150
# 510/510 [==============================] - 6s 12ms/step - loss: 5.5733 - accuracy: 0.1108
# Epoch 11/150
# 510/510 [==============================] - 6s 12ms/step - loss: 5.4840 - accuracy: 0.1141
# Epoch 12/150
# 510/510 [==============================] - 6s 12ms/step - loss: 5
150
# 510/510 [==============================] - 6s 12ms/step - loss: 2.0716 - accuracy: 0.6262
# Epoch 61/150
# 510/510 [==============================] - 6s 12ms/step - loss: 2.0439 - accuracy: 0.6315
# Epoch 62/150
# 510/510 [==============================] - 6s 13ms/step - loss: 2.0121 - accuracy: 0.6378
# Epoch 63/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.9811 - accuracy: 0.6439
# Epoch 64/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.9499 - accuracy: 0.6508
# Epoch 65/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.9269 - accuracy: 0.6551
# Epoch 66/150
# 510/510 [==============================] - 7s 14ms/step - loss: 1.9034 - accuracy: 0.6587
# Epoch 67/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.8696 - accuracy: 0.6662
# Epoch 68/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.8475 - accuracy: 0.6650
# Epoch 69/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.8267 - accuracy: 0.6740
# Epoch 70/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.8040 - accuracy: 0.6781
# Epoch 71/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.7775 - accuracy: 0.6841
# Epoch 72/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.7514 - accuracy: 0.6872
# Epoch 73/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.7253 - accuracy: 0.6920
# Epoch 74/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.7164 - accuracy: 0.6940
# Epoch 75/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.6924 - accuracy: 0.6960
# Epoch 76/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.6708 - accuracy: 0.7013
# Epoch 77/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.6468 - accuracy: 0.7058
# Epoch 78/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.6255 - accuracy: 0.7109
# Epoch 79/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.6088 - accuracy: 0.7150
# Epoch 80/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.6010 - accuracy: 0.7146
# Epoch 81/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.5790 - accuracy: 0.7216
# Epoch 82/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.5467 - accuracy: 0.7264
# Epoch 83/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.5319 - accuracy: 0.7294
# Epoch 84/150
# 510/510 [==============================] - 7s 14ms/step - loss: 1.5146 - accuracy: 0.7312
# Epoch 85/150
# 510/510 [==============================] - 6s 11ms/step - loss: 1.5003 - accuracy: 0.7352
# Epoch 86/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.4876 - accuracy: 0.7386
# Epoch 87/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.4761 - accuracy: 0.7345
# Epoch 88/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.4646 - accuracy: 0.7401
# Epoch 89/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.4351 - accuracy: 0.7475
# Epoch 90/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.4174 - accuracy: 0.7515
# Epoch 91/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.4125 - accuracy: 0.7518
# Epoch 92/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.4006 - accuracy: 0.7517
# Epoch 93/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.3988 - accuracy: 0.7510
# Epoch 94/150
# 510/510 [==============================] - 7s 13ms/step - loss: 1.3762 - accuracy: 0.7573
# Epoch 95/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.3582 - accuracy: 0.7606
# Epoch 96/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.3511 - accuracy: 0.7629
# Epoch 97/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.3298 - accuracy: 0.7647
# Epoch 98/150
# 510/510 [==============================] - 6s 13ms/step - loss: 1.3239 - accuracy: 0.7660
# Epoch 99/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.3155 - accuracy: 0.7691
# Epoch 100/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.2989 - accuracy: 0.7695
# Epoch 101/150
# 510/510 [==============================] - 7s 13ms/step - loss: 1.2880 - accuracy: 0.7746
# Epoch 102/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.2862 - accuracy: 0.7721
# Epoch 103/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.2739 - accuracy: 0.7748
# Epoch 104/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.2487 - accuracy: 0.7820
# Epoch 105/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.2487 - accuracy: 0.7804
# Epoch 106/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.2299 - accuracy: 0.7864
# Epoch 107/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.2192 - accuracy: 0.7846
# Epoch 108/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.2185 - accuracy: 0.7857
# Epoch 109/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.2089 - accuracy: 0.7879
# Epoch 110/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.2040 - accuracy: 0.7875
# Epoch 111/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.1862 - accuracy: 0.7901
# Epoch 112/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.1761 - accuracy: 0.7917
# Epoch 113/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.1781 - accuracy: 0.7907
# Epoch 114/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.1639 - accuracy: 0.7931
# Epoch 115/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.1633 - accuracy: 0.7957
# Epoch 116/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.1515 - accuracy: 0.7967
# Epoch 117/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.1400 - accuracy: 0.7977
# Epoch 118/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.1350 - accuracy: 0.7974
# Epoch 119/150
# 510/510 [==============================] - 7s 14ms/step - loss: 1.1237 - accuracy: 0.8022
# Epoch 120/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.1265 - accuracy: 0.7958
# Epoch 121/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.1128 - accuracy: 0.8014
# Epoch 122/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.0932 - accuracy: 0.8071
# Epoch 123/150
# 510/510 [==============================] - 6s 13ms/step - loss: 1.0920 - accuracy: 0.8053
# Epoch 124/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.0859 - accuracy: 0.8071
# Epoch 125/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.0813 - accuracy: 0.8082
# Epoch 126/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.0798 - accuracy: 0.8098
# Epoch 127/150
# 510/510 [==============================] - 6s 13ms/step - loss: 1.0788 - accuracy: 0.8068
# Epoch 128/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.0747 - accuracy: 0.8055
# Epoch 129/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.0626 - accuracy: 0.8099
# Epoch 130/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.0421 - accuracy: 0.8131
# Epoch 131/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.0371 - accuracy: 0.8137
# Epoch 132/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.0355 - accuracy: 0.8116
# Epoch 133/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.0366 - accuracy: 0.8122
# Epoch 134/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.0350 - accuracy: 0.8126
# Epoch 135/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.0232 - accuracy: 0.8148
# Epoch 136/150
# 510/510 [==============================] - 7s 13ms/step - loss: 1.0266 - accuracy: 0.8133
# Epoch 137/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.0245 - accuracy: 0.8136
# Epoch 138/150
# 510/510 [==============================] - 6s 13ms/step - loss: 1.0071 - accuracy: 0.8169
# Epoch 139/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.0054 - accuracy: 0.8171
# Epoch 140/150
# 510/510 [==============================] - 6s 12ms/step - loss: 1.0059 - accuracy: 0.8169
# Epoch 141/150
# 510/510 [==============================] - 6s 12ms/step - loss: 0.9928 - accuracy: 0.8222
# Epoch 142/150
# 510/510 [==============================] - 6s 12ms/step - loss: 0.9929 - accuracy: 0.8180
# Epoch 143/150
# 510/510 [==============================] - 6s 12ms/step - loss: 0.9850 - accuracy: 0.8188
# Epoch 144/150
# 510/510 [==============================] - 6s 12ms/step - loss: 0.9936 - accuracy: 0.8171
# Epoch 145/150
# 510/510 [==============================] - 6s 12ms/step - loss: 0.9782 - accuracy: 0.8195
# Epoch 146/150
# 510/510 [==============================] - 6s 12ms/step - loss: 0.9730 - accuracy: 0.8207
# Epoch 147/150
# 510/510 [==============================] - 6s 12ms/step - loss: 0.9788 - accuracy: 0.8187
# Epoch 148/150
# 510/510 [==============================] - 6s 13ms/step - loss: 0.9744 - accuracy: 0.8210
# Epoch 149/150
# 510/510 [==============================] - 6s 12ms/step - loss: 0.9734 - accuracy: 0.8213
# Epoch 150/150
# 510/510 [==============================] - 6s 12ms/step - loss: 0.9625 - accuracy: 0.8228

# %% [markdown]
# **GENERATING TEXT USING THE BUILT MODEL**

# %%
print('Enter the text to generate your poem:')
seed_text = input()
next_words = 50
ouptut_text = ""

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences(
        [token_list], maxlen=max_sequence_len-1,
      padding='pre')
    predicted = np.argmax(model.predict(token_list,
                                        verbose=0), axis=-1)
    output_word = ""

    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break

    seed_text += " " + output_word
l=seed_text.split(' ')
n=len(l)
print()
for i in range(0,n-5,5):
  print(l[i+0]," ",l[i+1]," ",l[i+2]," ",l[i+3]," ",l[i+4])
# Out:
# Enter the text to generate your poem:
# Life is
# Life   is   a   precious   rare
# jewel   mccree   two   presence   but
# a   tiny   trace   erins   isle
# are   erins   town   ever   saint
# patrick   the   hickory   i   recognized
# seen   the   bollin   sunbeam   night
# the   englishmen   saw   that   down
# as   i   mounted   the   platform
# high   bright   tree   to   look
# that   brave   far   from   your
